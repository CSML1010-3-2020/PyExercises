# %%
# Data Frames

# %%
import pandas as pd

# %%
# Method 1: Specify Full Path to File

# %%
stats = pd.read_csv('C:\\Users\\pauld\\Documents\\00_Apps\\Docs\\Training\\PJD\\Python3\\PythonAZ_4DataScienceWRealExcercices\\Section05\\P4-Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Method 2: Change Working DIrectory

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\pauld\Documents\00_Apps\Docs\Training\PJD\Python3\PythonAZ_4DataScienceWRealExcercices

# %%
os.chdir('C:\\Users\\Pauld\\Desktop')

# %%
print(os.getcwd())
# Out:
# C:\Users\Pauld\Desktop

# %%
os.chdir('C:\\Users\\pauld\\Documents\\00_Apps\\Docs\\Training\\PJD\\Python3\\PythonAZ_4DataScienceWRealExcercices\\Section05')

# %%
print(os.getcwd())
# Out:
# C:\Users\pauld\Documents\00_Apps\Docs\Training\PJD\Python3\PythonAZ_4DataScienceWRealExcercices\Section05

# %%
stats2 = pd.read_csv('P4-Demographic-Data.csv')

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# Review of Data Frame Commands
import pandas as pd
# Method 1: Specify Full Path to File
stats = pd.read_csv('C:\\Users\\pauld\\Documents\\00_Apps\\Docs\\Training\\PJD\\Python3\\PythonAZ_4DataScienceWRealExcercices\\Section05\\P4-Demographic-Data.csv')
stats
# Method 2: Change Working DIrectory
import os
print(os.getcwd())
os.chdir('C:\\Users\\Pauld\\Desktop')
print(os.getcwd())
os.chdir('C:\\Users\\pauld\\Documents\\00_Apps\\Docs\\Training\\PJD\\Python3\\PythonAZ_4DataScienceWRealExcercices\\Section05')
print(os.getcwd())
stats2 = pd.read_csv('P4-Demographic-Data.csv')
stats2
# Out:
# C:\Users\pauld\Documents\00_Apps\Docs\Training\PJD\Python3\PythonAZ_4DataScienceWRealExcercices\Section05
# C:\Users\Pauld\Desktop
# C:\Users\pauld\Documents\00_Apps\Docs\Training\PJD\Python3\PythonAZ_4DataScienceWRealExcercices\Section05
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# ...

# %% [markdown]
# ---

# %%
### Exploring The Data

# %%
#1 View
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#2 Number of Rows
len(stats)  # 195 rows imported - good practice to check and record
# Out:
# 195

# %%
#3 See columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#4 Number of columns
len(stats.columns)
# Out:
# 5

# %%
#5 Top Rows
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(8)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
# 7   Antigua and Barbuda          ATG      16.447            63.4
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
#6 Bottom Rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#7 Information on the columns
stats.info()  # like the str function in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8 Get Stats on the numeric columns
stats.describe()  # like the summary function in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# ---

# %%
# Renaming Columns of a Dataframe

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['a','b','c','d','e']

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns = ['CountryName', 
                 'CountryCode', 
                 'BirthRate', 
                 'InternetUsers',
                 'IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %% [markdown]
# ## Subsetting Dataframes in Pandas

# %%
# Three parts:
# -Rows
# -Columns
# -Combine the two

# %%
# Part 1. Rows
stats[100:110]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 100             Libya         LBY     21.425        16.5000
# 101         St. Lucia         LCA     15.430        46.2000
# 102     Liechtenstein         LIE      9.200        93.8000
# 103         Sri Lanka         LKA     17.863        21.9000
# 104           Lesotho         LSO     28.738         5.0000
# 105         Lithuania         LTU     10.100        68.4529
# 106        Luxembourg         LUX     11.300        93.7765
# 107            Latvia         LVA     10.200        75.2344
# 108  Macao SAR, China         MAC     11.256        65.8000
# 109           Morocco         MAR     21.023        56.0000
#
#              IncomeGroup
# 100  Upper middle income
# 101  Upper middle income
# 102          High income
# 103  Lower middle income
# 104  Lower middle income
# 105          High income
# 106          High income
# 107          High income
# 108          High income
# 109  Lower middle income

# %%
stats[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
# Quick excercise
# Reverse the dataframe
stats[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# Excercise
# Get every 20th row
stats[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
# Part 2 Columns

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
stats['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
# Extract two columns
stats[['CountryName', 'BirthRate']].head()
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
stats[['BirthRate','CountryName']].head()
# Out:
#    BirthRate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
# Quick Access - Requires the name to be one word

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.CountryCode.head()
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# Name: CountryCode, dtype: object

# %%
stats.CountryCode[3:5]
# Out:
# 3    ALB
# 4    ARE
# Name: CountryCode, dtype: object

# %%
#3 Combining the two

# %%
stats[4:8][['BirthRate','CountryName']]
# Out:
#    BirthRate           CountryName
# 4     11.044  United Arab Emirates
# 5     17.716             Argentina
# 6     13.308               Armenia
# 7     16.447   Antigua and Barbuda

# %% [markdown]
# ---

# %% [markdown]
# ## Basic Operations on a DataFrame

# %%
# Mathematical Operations:
result = stats.BirthRate * stats.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
# Add a column to a dataframe:

# %%
stats['MyCalc'] = stats.BirthRate * stats.InternetUsers

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
# Comparison to R
# stats['xyz'] = [1,2,3,4,5] # Gives an error in Python, no error in R as R fills the column with values from the vector

# %%
# Removin a column

# %% [markdown]
# stats.drop('MyCalc', axis=1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats = stats.drop('MyCalc', axis=1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %% [markdown]
# ## Filtering Data Frames

# %%
# Filtering is about Rows

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.InternetUsers < 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter = stats.InternetUsers < 2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[30:40]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 30         Canada         CAN     10.900          85.80          High income
# 31    Switzerland         CHE     10.200          86.34          High income
# 32          Chile         CHL     13.385          66.50          High income
# 33          China         CHN     12.100          45.80  Upper middle income
# 34  Cote d'Ivoire         CIV     37.320           8.40  Lower middle income
# 35       Cameroon         CMR     37.236           6.40  Lower middle income
# 36    Congo, Rep.         COG     37.011           6.60  Lower middle income
# 37       Colombia         COL     16.076          51.70  Upper middle income
# 38        Comoros         COM     34.326           6.50           Low income
# 39     Cabo Verde         CPV     21.625          37.50  Lower middle income

# %%
stats[Filter] # Conceptually this is just like R
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
stats.BirthRate > 40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
Filter2 = stats.BirthRate > 40

# %%
stats[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats[stats.InternetUsers > 30]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244           78.9
# 3                  Albania         ALB     12.877           57.2
# 4     United Arab Emirates         ARE     11.044           88.0
# 5                Argentina         ARG     17.716           59.9
# 6                  Armenia         ARM     13.308           41.9
# ..                     ...         ...        ...            ...
# 184          Venezuela, RB         VEN     19.842           54.9
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 188     West Bank and Gaza         PSE     30.394           46.6
# 191           South Africa         ZAF     20.850           46.5
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# ..                   ...
# ...

# %%
#stats[stats.BirthRate > 40 and stats.InternetUsers <2] # Error Why? 
# Because can't make a decision on the list of values (some true some false; not 1 unique decision)

# %%
stats[Filter & Filter2]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats[(stats.BirthRate > 40) & (stats.InternetUsers <2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
stats.head
# Out:
# <bound method NDFrame.head of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats[stats.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
# How to get the unique categories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# Excercise: Find the country: Malta

# %%
stats[stats.CountryName == 'Malta']
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %% [markdown]
# ---

# %% [markdown]
# ## Accessing individual Elements

# %%
# stats[2,2] # Error Why?

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# .at     # For labels. Important: event integers are treated as labels
# .iat    # for integer location

# %%
stats.iat[1,4]
# Out:
# 'Low income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[2, 'BirthRate']
# Out:
# 45.985

# %%
# why we need .at:

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,'CountryName']
# Out:
# 'Azerbaijan'

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 20,10  # Sets the size of the graph
# %matplotlib inline

# %%
# Distribution

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
vis1 = sns.distplot(stats["InternetUsers"], bins=5)

# %%
vis1 = sns.distplot(stats["InternetUsers"],)

# %%
vis2 = sns.boxplot(data=stats, x="IncomeGroup", y="BirthRate") # IncomeGroup

# %%
# Seaborn Gallery

# %% [markdown]
# ---

# %% [markdown]
# ## Seaborn Gallery
# The Seaborn Gallery package allows for many

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Capture the original matplotlib rcParams
#
# PACKAGE CONTENTS
#     algorithms
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     conftest
#     distributions
#     external (package)
#     matrix
#     miscplot
#     palettes
#     rcmod
#     regression
#     relational
#     tests (package)
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.10.0
#
# FILE
#     c:\users\pauld\anaconda3\lib\site-packages\seaborn\__init__.py

# %% [markdown]
# Looking at the boxplot function of the Seaborn package

# %%
help(sns.lmplot)
# Out:
# Help on function lmplot in module seaborn.regression:
#
# lmplot(x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, size=None)
#     Plot data and regression model fits across a FacetGrid.
#
#     This function combines :func:`regplot` and :class:`FacetGrid`. It is
#     intended as a convenient interface to fit regression models across
#     conditional subsets of a dataset.
#
#     When thinking about how to assign variables to different facets, a general
#     rule is that it makes sense to use ``hue`` for the most important
# ...

# %% [markdown]
# Using the Seaborn package to create a plot

# %%
sns.lmplot
# Out:
# <function seaborn.regression.lmplot(x, y, data, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, size=None)>

# %%
vis3 = sns.lmplot(data=stats,x='InternetUsers',y='BirthRate', height=5, fit_reg=False)

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_orig_rc_params',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'external',
#  'factorplot',
#  'get_dataset_names',
#  'heatmap',
#  'hls_palette',
#  'husl_palette',
#  'jointplot',
#  'kdeplot',
#  'light_palette',
#  'lineplot',
#  'lmplot',
#  'load_dataset',
#  'lvplot',
# ...

# %%
vis4 = sns.distplot(stats["BirthRate"], bins=5, aspect=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-212c2da69bdb> in <module>
# ----> 1 vis4 = sns.distplot(stats["BirthRate"], bins=5, aspect=2)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Set the background grid using the set() function

# %%
# This was set automatically in versions of Seaborn prior to 0.8?  Now needs to be manually called
sns.set()

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', \
                  fit_reg=False, hue='IncomeGroup', height=10, aspect=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Keyword Arguments in Python

# %% [markdown]
# ### Keyword Arguments in Python (advanced tutorial)

# %%
sns.lmplot?

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', \
                  fit_reg=False, hue='IncomeGroup', height=5, aspect=1, \
                  scatter_kws={"s":100}, \
                  y_jitter={}
# Out:
#   File "<ipython-input-118-c52a1e231a1b>", line 4
#     y_jitter={}
#                ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# To look at the help for a function

# %%
sns.lmplot?

# %% [markdown]
# Examining the parameters of lmplot, we find that there are
# {scatter,line}_kws : dictionaries
#     Additional keyword arguments to pass to ``plt.scatter`` and
#     ``plt.plot``.

# %%
plt.plot?

# %% [markdown]
# {x,y}_jitter : floats, optional
#     Add uniform random noise of this size to either the ``x`` or ``y``
#     variables. The noise is added to a copy of the data after fitting the
#     regression, and only influences the look of the scatterplot. This can
#     be helpful when plotting variables that take discrete values.
